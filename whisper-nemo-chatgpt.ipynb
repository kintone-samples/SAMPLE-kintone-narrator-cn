# %% [markdown]
# # Whisper+Nemo+ChatGPT实现音视频内容总结

# %% [markdown]
# [![Open in Kaggle](https://kaggle.com/static/images/open-in-kaggle.svg)](https://www.kaggle.com/code/cybozucyao/sample-kintone-narrator-cn/notebook)
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/kintone-samples/SAMPLE-kintone-narrator-cn/blob/main/whisper-nemo-chatgpt.ipynb)

# %% [markdown]
# ## 安装依赖

# %%
# !pip install yt_dlp
# !pip install git+https://github.com/facebookresearch/demucs#egg=demucs
# !pip install openai tiktoken
# !pip3 install torch torchvision torchaudio
# !pip install git+https://github.com/m-bain/whisperx.git
# !pip install faster_whisper
# !apt install -y ffmpeg sox libsndfile1
# !pip install --upgrade hydra-core llvmlite omegaconf --ignore-installed
# !python -m pip install git+https://github.com/NVIDIA/NeMo.git@main
# !pip install --upgrade Cython jiwer braceexpand webdataset librosa sentencepiece
# !pip install --upgrade youtokentome pyannote-audio transformers pandas inflect editdistance
# !pip install -U pytorch-lightning
# Out:
# Collecting yt_dlp
#   Downloading yt_dlp-2023.7.6-py2.py3-none-any.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 39.4 MB/s eta 0:00:0000:0100:01
# Collecting mutagen (from yt_dlp)
#   Downloading mutagen-1.47.0-py3-none-any.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.4/194.4 kB 20.7 MB/s eta 0:00:00
# Collecting pycryptodomex (from yt_dlp)
#   Downloading pycryptodomex-3.18.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 70.3 MB/s eta 0:00:00
# Requirement already satisfied: websockets in /opt/conda/lib/python3.10/site-packages (from yt_dlp) (11.0.3)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from yt_dlp) (2023.5.7)
# Collecting brotli (from yt_dlp)
#   Downloading Brotli-1.0.9-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 74.7 MB/s eta 0:00:00:00:01
# Installing collected packages: brotli, pycryptodomex, mutagen, yt_dlp
# Successfully installed brotli-1.0.9 mutagen-1.47.0 pycryptodomex-3.18.0 yt_dlp-2023.7.6
# Collecting demucs
#   Cloning https://github.com/facebookresearch/demucs to /tmp/pip-install-55exy__3/demucs_8b8ae65a968b464da0f0a1cc9714600e
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/demucs /tmp/pip-install-55exy__3/demucs_8b8ae65a968b464da0f0a1cc9714600e
#   Resolved https://github.com/facebookresearch/demucs to commit 404690cb2555d767312cb2cee8a68a6d7bff018d
#   Preparing metadata (setup.py) ... done
# Collecting dora-search (from demucs)
#   Downloading dora_search-0.1.12.tar.gz (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.1/87.1 kB 3.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting einops (from demucs)
#   Downloading einops-0.6.1-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 3.7 MB/s eta 0:00:00
# Collecting julius>=0.2.3 (from demucs)
#   Downloading julius-0.2.7.tar.gz (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 6.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting lameenc>=1.2 (from demucs)
#   Downloading lameenc-1.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (267 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.2/267.2 kB 19.4 MB/s eta 0:00:00
# Collecting openunmix (from demucs)
#   Downloading openunmix-1.2.1-py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.7/46.7 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from demucs) (6.0)
# Requirement already satisfied: torch>=1.8.1 in /opt/conda/lib/python3.10/site-packages (from demucs) (2.0.0)
# Requirement already satisfied: torchaudio>=0.8 in /opt/conda/lib/python3.10/site-packages (from demucs) (2.0.1)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from demucs) (4.65.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.1->demucs) (3.12.2)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.1->demucs) (4.6.3)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.1->demucs) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.1->demucs) (3.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.1->demucs) (3.1.2)
# Collecting omegaconf (from dora-search->demucs)
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 7.9 MB/s eta 0:00:00
# Requirement already satisfied: retrying in /opt/conda/lib/python3.10/site-packages (from dora-search->demucs) (1.3.3)
# Collecting submitit (from dora-search->demucs)
#   Downloading submitit-1.4.5-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 7.9 MB/s eta 0:00:00
# Collecting treetable (from dora-search->demucs)
#   Downloading treetable-0.2.5.tar.gz (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from openunmix->demucs) (1.23.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.8.1->demucs) (2.1.3)
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf->dora-search->demucs)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 11.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six>=1.7.0 in /opt/conda/lib/python3.10/site-packages (from retrying->dora-search->demucs) (1.16.0)
# Requirement already satisfied: cloudpickle>=1.2.1 in /opt/conda/lib/python3.10/site-packages (from submitit->dora-search->demucs) (2.2.1)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.8.1->demucs) (1.3.0)
# Building wheels for collected packages: demucs, julius, dora-search, antlr4-python3-runtime, treetable
#   Building wheel for demucs (setup.py) ... done
#   Created wheel for demucs: filename=demucs-4.0.1a3-py3-none-any.whl size=85745 sha256=788f803220e34921bf0b9cc4d80ffaf941f919c3c19652da4457f15077404e9a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-l53znrz1/wheels/45/e4/ca/7791f04b554e5433713e22900eaf11595e27c454fb65ac30ab
#   Building wheel for julius (setup.py) ... done
#   Created wheel for julius: filename=julius-0.2.7-py3-none-any.whl size=21895 sha256=bd1739dc12f32fb901dc8ef5f63ddf579907ee070f837e6a3a9e2ba6478ea7a5
#   Stored in directory: /root/.cache/pip/wheels/b9/b2/05/f883527ffcb7f2ead5438a2c23439aa0c881eaa9a4c80256f4
#   Building wheel for dora-search (pyproject.toml) ... done
#   Created wheel for dora-search: filename=dora_search-0.1.12-py3-none-any.whl size=75090 sha256=094e740f41e7cf82955ed885f0c41986cff41592aedc7464417a823a7aa35364
#   Stored in directory: /root/.cache/pip/wheels/b1/c2/c0/bea5cc405497284d584b958f293ef32c23bad42ae5e44d973c
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144574 sha256=4d700ca4bdb5d4ce16f6a8a0c5e4c71b9f967c74ab5977bc5182302bfe6207d2
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
#   Building wheel for treetable (setup.py) ... done
#   Created wheel for treetable: filename=treetable-0.2.5-py3-none-any.whl size=7350 sha256=f489088c804e67953ba63420fdb68bdade51c31b6d3efb7ecb253cbfae77a8cc
#   Stored in directory: /root/.cache/pip/wheels/72/55/0e/91c3655bdb162446f8a7cd477579397544454a63ae7c599c0c
# Successfully built demucs julius dora-search antlr4-python3-runtime treetable
# Installing collected packages: lameenc, antlr4-python3-runtime, treetable, submitit, omegaconf, einops, julius, dora-search, openunmix, demucs
# Successfully installed antlr4-python3-runtime-4.9.3 demucs-4.0.1a3 dora-search-0.1.12 einops-0.6.1 julius-0.2.7 lameenc-1.6.1 omegaconf-2.3.0 openunmix-1.2.1 submitit-1.4.5 treetable-0.2.5
# Collecting openai
#   Downloading openai-0.28.0-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 3.5 MB/s eta 0:00:00
# Collecting tiktoken
#   Downloading tiktoken-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 35.4 MB/s eta 0:00:0000:01
# Requirement already satisfied: requests>=2.20 in /opt/conda/lib/python3.10/site-packages (from openai) (2.31.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from openai) (4.65.0)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from openai) (3.8.4)
# Requirement already satisfied: regex>=2022.1.18 in /opt/conda/lib/python3.10/site-packages (from tiktoken) (2023.6.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.20->openai) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.20->openai) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.20->openai) (2023.5.7)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->openai) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->openai) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/conda/lib/python3.10/site-packages (from aiohttp->openai) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->openai) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->openai) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->openai) (1.3.1)
# Installing collected packages: tiktoken, openai
# Successfully installed openai-0.28.0 tiktoken-0.4.0
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (2.0.0)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.10/site-packages (0.15.1)
# Requirement already satisfied: torchaudio in /opt/conda/lib/python3.10/site-packages (2.0.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch) (3.12.2)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch) (4.6.3)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch) (3.1.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torchvision) (1.23.5)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torchvision) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision) (9.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (2023.5.7)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch) (1.3.0)
# Collecting git+https://github.com/m-bain/whisperx.git
#   Cloning https://github.com/m-bain/whisperx.git to /tmp/pip-req-build-6vvoibst
#   Running command git clone --filter=blob:none --quiet https://github.com/m-bain/whisperx.git /tmp/pip-req-build-6vvoibst
#   Resolved https://github.com/m-bain/whisperx.git to commit 15d9e08d3ecc9fb735ca11e74590fc89ea9ae3ee
#   Preparing metadata (setup.py) ... done
# Collecting pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317 (from whisperx==3.1.1)
#   Cloning https://github.com/pyannote/pyannote-audio (to revision 11b56a137a578db9335efc00298f6ec1932e6317) to /tmp/pip-install-72jzn7bq/pyannote-audio_8ea4b3a2968f440ba27585f2d3057d12
#   Running command git clone --filter=blob:none --quiet https://github.com/pyannote/pyannote-audio /tmp/pip-install-72jzn7bq/pyannote-audio_8ea4b3a2968f440ba27585f2d3057d12
#   Running command git rev-parse -q --verify 'sha^11b56a137a578db9335efc00298f6ec1932e6317'
#   Running command git fetch -q https://github.com/pyannote/pyannote-audio 11b56a137a578db9335efc00298f6ec1932e6317
#   Running command git checkout -q 11b56a137a578db9335efc00298f6ec1932e6317
#   Resolved https://github.com/pyannote/pyannote-audio to commit 11b56a137a578db9335efc00298f6ec1932e6317
#   Running command git submodule update --init --recursive -q
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=2 in /opt/conda/lib/python3.10/site-packages (from whisperx==3.1.1) (2.0.0)
# Requirement already satisfied: torchaudio>=2 in /opt/conda/lib/python3.10/site-packages (from whisperx==3.1.1) (2.0.1)
# Collecting faster-whisper (from whisperx==3.1.1)
#   Downloading faster_whisper-0.8.0-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 26.1 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: transformers in /opt/conda/lib/python3.10/site-packages (from whisperx==3.1.1) (4.30.2)
# Collecting ffmpeg-python>=0.2 (from whisperx==3.1.1)
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from whisperx==3.1.1) (1.5.3)
# Collecting setuptools>=65 (from whisperx==3.1.1)
#   Using cached setuptools-68.1.2-py3-none-any.whl (805 kB)
# Requirement already satisfied: nltk in /opt/conda/lib/python3.10/site-packages (from whisperx==3.1.1) (3.2.4)
# Requirement already satisfied: future in /opt/conda/lib/python3.10/site-packages (from ffmpeg-python>=0.2->whisperx==3.1.1) (0.18.3)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=2->whisperx==3.1.1) (3.12.2)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=2->whisperx==3.1.1) (4.6.3)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=2->whisperx==3.1.1) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=2->whisperx==3.1.1) (3.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=2->whisperx==3.1.1) (3.1.2)
# Collecting av==10.* (from faster-whisper->whisperx==3.1.1)
#   Downloading av-10.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.0/31.0 MB 41.3 MB/s eta 0:00:0000:0100:01
# Collecting ctranslate2<4,>=3.17 (from faster-whisper->whisperx==3.1.1)
#   Downloading ctranslate2-3.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (35.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.7/35.7 MB 35.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: huggingface-hub>=0.13 in /opt/conda/lib/python3.10/site-packages (from faster-whisper->whisperx==3.1.1) (0.16.4)
# Requirement already satisfied: tokenizers==0.13.* in /opt/conda/lib/python3.10/site-packages (from faster-whisper->whisperx==3.1.1) (0.13.3)
# Collecting onnxruntime<2,>=1.14 (from faster-whisper->whisperx==3.1.1)
#   Downloading onnxruntime-1.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 80.0 MB/s eta 0:00:00:00:0100:01
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from nltk->whisperx==3.1.1) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/conda/lib/python3.10/site-packages (from pandas->whisperx==3.1.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->whisperx==3.1.1) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /opt/conda/lib/python3.10/site-packages (from pandas->whisperx==3.1.1) (1.23.5)
# Collecting asteroid-filterbanks>=0.4 (from pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1)
#   Downloading asteroid_filterbanks-0.4.0-py3-none-any.whl (29 kB)
# Requirement already satisfied: einops>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (0.6.1)
# Collecting lightning>=2.0.1 (from pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1)
#   Downloading lightning-2.0.8-py3-none-any.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 78.3 MB/s eta 0:00:00
# Requirement already satisfied: omegaconf<3.0,>=2.1 in /opt/conda/lib/python3.10/site-packages (from pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (2.3.0)
# Collecting pyannote.core>=5.0.0 (from pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1)
#   Downloading pyannote.core-5.0.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.5/58.5 kB 4.7 MB/s eta 0:00:00
# Collecting pyannote.database>=5.0.1 (from pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1)
#   Downloading pyannote.database-5.0.1-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 kB 3.9 MB/s eta 0:00:00
# Collecting pyannote.metrics>=3.2 (from pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1)
#   Downloading pyannote.metrics-3.2.1-py3-none-any.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.4/51.4 kB 4.8 MB/s eta 0:00:00
# Collecting pyannote.pipeline>=2.3 (from pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1)
#   Downloading pyannote.pipeline-2.3-py3-none-any.whl (30 kB)
# Collecting pytorch_metric_learning>=2.1.0 (from pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1)
#   Downloading pytorch_metric_learning-2.3.0-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 11.5 MB/s eta 0:00:00
# Requirement already satisfied: rich>=12.0.0 in /opt/conda/lib/python3.10/site-packages (from pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (13.4.2)
# Requirement already satisfied: semver>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (3.0.1)
# Requirement already satisfied: soundfile>=0.12.1 in /opt/conda/lib/python3.10/site-packages (from pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (0.12.1)
# Collecting speechbrain>=0.5.14 (from pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1)
#   Downloading speechbrain-0.5.15-py3-none-any.whl (553 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 553.8/553.8 kB 41.5 MB/s eta 0:00:00
# Requirement already satisfied: tensorboardX>=2.6 in /opt/conda/lib/python3.10/site-packages (from pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (2.6)
# Collecting torch_audiomentations>=0.11.0 (from pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1)
#   Downloading torch_audiomentations-0.11.0-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.9/47.9 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: torchmetrics>=0.11.0 in /opt/conda/lib/python3.10/site-packages (from pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (1.0.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from transformers->whisperx==3.1.1) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers->whisperx==3.1.1) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers->whisperx==3.1.1) (2023.6.3)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from transformers->whisperx==3.1.1) (2.31.0)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/conda/lib/python3.10/site-packages (from transformers->whisperx==3.1.1) (0.3.1)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers->whisperx==3.1.1) (4.65.0)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.13->faster-whisper->whisperx==3.1.1) (2023.6.0)
# Requirement already satisfied: arrow<3.0,>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from lightning>=2.0.1->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (1.2.3)
# Requirement already satisfied: backoff<4.0,>=2.2.1 in /opt/conda/lib/python3.10/site-packages (from lightning>=2.0.1->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (2.2.1)
# Requirement already satisfied: beautifulsoup4<6.0,>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from lightning>=2.0.1->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (4.12.2)
# Requirement already satisfied: click<10.0 in /opt/conda/lib/python3.10/site-packages (from lightning>=2.0.1->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (8.1.3)
# Collecting croniter<1.5.0,>=1.3.0 (from lightning>=2.0.1->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1)
#   Downloading croniter-1.4.1-py2.py3-none-any.whl (19 kB)
# Collecting dateutils<2.0 (from lightning>=2.0.1->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1)
#   Downloading dateutils-0.6.12-py2.py3-none-any.whl (5.7 kB)
# Collecting deepdiff<8.0,>=5.7.0 (from lightning>=2.0.1->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1)
#   Downloading deepdiff-6.4.1-py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.9/70.9 kB 7.5 MB/s eta 0:00:00
# Requirement already satisfied: fastapi<2.0,>=0.92.0 in /opt/conda/lib/python3.10/site-packages (from lightning>=2.0.1->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (0.98.0)
# Collecting inquirer<5.0,>=2.10.0 (from lightning>=2.0.1->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1)
#   Downloading inquirer-3.1.3-py3-none-any.whl (18 kB)
# Collecting lightning-cloud>=0.5.37 (from lightning>=2.0.1->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1)
#   Downloading lightning_cloud-0.5.37-py3-none-any.whl (596 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 596.7/596.7 kB 40.6 MB/s eta 0:00:00
# Requirement already satisfied: lightning-utilities<2.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from lightning>=2.0.1->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (0.9.0)
# Requirement already satisfied: psutil<7.0 in /opt/conda/lib/python3.10/site-packages (from lightning>=2.0.1->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (5.9.3)
# Requirement already satisfied: pydantic<2.2.0,>=1.7.4 in /opt/conda/lib/python3.10/site-packages (from lightning>=2.0.1->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (1.10.10)
# Collecting python-multipart<2.0,>=0.0.5 (from lightning>=2.0.1->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1)
#   Downloading python_multipart-0.0.6-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: starlette in /opt/conda/lib/python3.10/site-packages (from lightning>=2.0.1->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (0.27.0)
# Collecting starsessions<2.0,>=1.2.1 (from lightning>=2.0.1->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1)
#   Downloading starsessions-1.3.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: traitlets<7.0,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from lightning>=2.0.1->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (5.9.0)
# Requirement already satisfied: urllib3<4.0 in /opt/conda/lib/python3.10/site-packages (from lightning>=2.0.1->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (1.26.15)
# Requirement already satisfied: uvicorn<2.0 in /opt/conda/lib/python3.10/site-packages (from lightning>=2.0.1->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (0.22.0)
# Requirement already satisfied: websocket-client<3.0 in /opt/conda/lib/python3.10/site-packages (from lightning>=2.0.1->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (1.6.0)
# Requirement already satisfied: websockets<13.0 in /opt/conda/lib/python3.10/site-packages (from lightning>=2.0.1->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (11.0.3)
# Requirement already satisfied: pytorch-lightning in /opt/conda/lib/python3.10/site-packages (from lightning>=2.0.1->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (2.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=2->whisperx==3.1.1) (2.1.3)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /opt/conda/lib/python3.10/site-packages (from omegaconf<3.0,>=2.1->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (4.9.3)
# Collecting coloredlogs (from onnxruntime<2,>=1.14->faster-whisper->whisperx==3.1.1)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /opt/conda/lib/python3.10/site-packages (from onnxruntime<2,>=1.14->faster-whisper->whisperx==3.1.1) (23.5.26)
# Requirement already satisfied: protobuf in /opt/conda/lib/python3.10/site-packages (from onnxruntime<2,>=1.14->faster-whisper->whisperx==3.1.1) (3.20.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->transformers->whisperx==3.1.1) (3.0.9)
# Requirement already satisfied: sortedcontainers>=2.0.4 in /opt/conda/lib/python3.10/site-packages (from pyannote.core>=5.0.0->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (2.4.0)
# Requirement already satisfied: scipy>=1.1 in /opt/conda/lib/python3.10/site-packages (from pyannote.core>=5.0.0->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (1.11.1)
# Requirement already satisfied: typer[all]>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from pyannote.database>=5.0.1->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (0.9.0)
# Requirement already satisfied: scikit-learn>=0.17.1 in /opt/conda/lib/python3.10/site-packages (from pyannote.metrics>=3.2->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (1.2.2)
# Requirement already satisfied: docopt>=0.6.2 in /opt/conda/lib/python3.10/site-packages (from pyannote.metrics>=3.2->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (0.6.2)
# Requirement already satisfied: tabulate>=0.7.7 in /opt/conda/lib/python3.10/site-packages (from pyannote.metrics>=3.2->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (0.9.0)
# Requirement already satisfied: matplotlib>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from pyannote.metrics>=3.2->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (3.7.1)
# Requirement already satisfied: optuna>=1.4 in /opt/conda/lib/python3.10/site-packages (from pyannote.pipeline>=2.3->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (3.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->transformers->whisperx==3.1.1) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->transformers->whisperx==3.1.1) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->transformers->whisperx==3.1.1) (2023.5.7)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich>=12.0.0->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich>=12.0.0->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (2.15.1)
# Requirement already satisfied: cffi>=1.0 in /opt/conda/lib/python3.10/site-packages (from soundfile>=0.12.1->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (1.15.1)
# Collecting hyperpyyaml (from speechbrain>=0.5.14->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1)
#   Downloading HyperPyYAML-1.2.1-py3-none-any.whl (16 kB)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from speechbrain>=0.5.14->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (1.2.0)
# Requirement already satisfied: sentencepiece in /opt/conda/lib/python3.10/site-packages (from speechbrain>=0.5.14->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (0.1.99)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=2->whisperx==3.1.1) (1.3.0)
# Requirement already satisfied: julius<0.3,>=0.2.3 in /opt/conda/lib/python3.10/site-packages (from torch_audiomentations>=0.11.0->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (0.2.7)
# Requirement already satisfied: librosa>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from torch_audiomentations>=0.11.0->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (0.10.0.post2)
# Collecting torch-pitch-shift>=1.2.2 (from torch_audiomentations>=0.11.0->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1)
#   Downloading torch_pitch_shift-1.2.4-py3-none-any.whl (4.9 kB)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4<6.0,>=4.8.0->lightning>=2.0.1->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (2.3.2.post1)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=1.0->soundfile>=0.12.1->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (2.21)
# Collecting ordered-set<4.2.0,>=4.0.2 (from deepdiff<8.0,>=5.7.0->lightning>=2.0.1->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1)
#   Downloading ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/conda/lib/python3.10/site-packages (from fsspec->huggingface-hub>=0.13->faster-whisper->whisperx==3.1.1) (3.8.4)
# Requirement already satisfied: blessed>=1.19.0 in /opt/conda/lib/python3.10/site-packages (from inquirer<5.0,>=2.10.0->lightning>=2.0.1->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (1.20.0)
# Collecting python-editor>=1.0.4 (from inquirer<5.0,>=2.10.0->lightning>=2.0.1->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1)
#   Downloading python_editor-1.0.4-py3-none-any.whl (4.9 kB)
# Collecting readchar>=3.0.6 (from inquirer<5.0,>=2.10.0->lightning>=2.0.1->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1)
#   Downloading readchar-4.0.5-py3-none-any.whl (8.5 kB)
# Requirement already satisfied: audioread>=2.1.9 in /opt/conda/lib/python3.10/site-packages (from librosa>=0.6.0->torch_audiomentations>=0.11.0->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (3.0.0)
# Requirement already satisfied: decorator>=4.3.0 in /opt/conda/lib/python3.10/site-packages (from librosa>=0.6.0->torch_audiomentations>=0.11.0->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in /opt/conda/lib/python3.10/site-packages (from librosa>=0.6.0->torch_audiomentations>=0.11.0->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (0.57.1)
# Requirement already satisfied: pooch<1.7,>=1.0 in /opt/conda/lib/python3.10/site-packages (from librosa>=0.6.0->torch_audiomentations>=0.11.0->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (1.6.0)
# Requirement already satisfied: soxr>=0.3.2 in /opt/conda/lib/python3.10/site-packages (from librosa>=0.6.0->torch_audiomentations>=0.11.0->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (0.3.5)
# Requirement already satisfied: lazy-loader>=0.1 in /opt/conda/lib/python3.10/site-packages (from librosa>=0.6.0->torch_audiomentations>=0.11.0->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (0.2)
# Requirement already satisfied: msgpack>=1.0 in /opt/conda/lib/python3.10/site-packages (from librosa>=0.6.0->torch_audiomentations>=0.11.0->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (1.0.5)
# Requirement already satisfied: pyjwt in /opt/conda/lib/python3.10/site-packages (from lightning-cloud>=0.5.37->lightning>=2.0.1->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (2.7.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (0.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (9.5.0)
# Requirement already satisfied: alembic>=1.5.0 in /opt/conda/lib/python3.10/site-packages (from optuna>=1.4->pyannote.pipeline>=2.3->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (1.11.1)
# Requirement already satisfied: cmaes>=0.9.1 in /opt/conda/lib/python3.10/site-packages (from optuna>=1.4->pyannote.pipeline>=2.3->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (0.9.1)
# Requirement already satisfied: colorlog in /opt/conda/lib/python3.10/site-packages (from optuna>=1.4->pyannote.pipeline>=2.3->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (6.7.0)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /opt/conda/lib/python3.10/site-packages (from optuna>=1.4->pyannote.pipeline>=2.3->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (2.0.17)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.17.1->pyannote.metrics>=3.2->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (3.1.0)
# Requirement already satisfied: anyio<5,>=3.4.0 in /opt/conda/lib/python3.10/site-packages (from starlette->lightning>=2.0.1->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (3.7.0)
# Requirement already satisfied: itsdangerous<3.0.0,>=2.0.1 in /opt/conda/lib/python3.10/site-packages (from starsessions<2.0,>=1.2.1->lightning>=2.0.1->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (2.1.2)
# Collecting primePy>=1.3 (from torch-pitch-shift>=1.2.2->torch_audiomentations>=0.11.0->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1)
#   Downloading primePy-1.3-py3-none-any.whl (4.0 kB)
# Requirement already satisfied: colorama<0.5.0,>=0.4.3 in /opt/conda/lib/python3.10/site-packages (from typer[all]>=0.2.1->pyannote.database>=5.0.1->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (0.4.6)
# Requirement already satisfied: shellingham<2.0.0,>=1.3.0 in /opt/conda/lib/python3.10/site-packages (from typer[all]>=0.2.1->pyannote.database>=5.0.1->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (1.5.1)
# Requirement already satisfied: h11>=0.8 in /opt/conda/lib/python3.10/site-packages (from uvicorn<2.0->lightning>=2.0.1->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (0.14.0)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime<2,>=1.14->faster-whisper->whisperx==3.1.1)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.5 MB/s eta 0:00:00
# Collecting ruamel.yaml<=0.17.28,>=0.17.8 (from hyperpyyaml->speechbrain>=0.5.14->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1)
#   Downloading ruamel.yaml-0.17.28-py3-none-any.whl (109 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.6/109.6 kB 10.9 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->huggingface-hub>=0.13->faster-whisper->whisperx==3.1.1) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->huggingface-hub>=0.13->faster-whisper->whisperx==3.1.1) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->huggingface-hub>=0.13->faster-whisper->whisperx==3.1.1) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->huggingface-hub>=0.13->faster-whisper->whisperx==3.1.1) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->huggingface-hub>=0.13->faster-whisper->whisperx==3.1.1) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->huggingface-hub>=0.13->faster-whisper->whisperx==3.1.1) (1.3.1)
# Requirement already satisfied: Mako in /opt/conda/lib/python3.10/site-packages (from alembic>=1.5.0->optuna>=1.4->pyannote.pipeline>=2.3->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (1.2.4)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.10/site-packages (from anyio<5,>=3.4.0->starlette->lightning>=2.0.1->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (1.3.0)
# Requirement already satisfied: exceptiongroup in /opt/conda/lib/python3.10/site-packages (from anyio<5,>=3.4.0->starlette->lightning>=2.0.1->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (1.1.1)
# Requirement already satisfied: wcwidth>=0.1.4 in /opt/conda/lib/python3.10/site-packages (from blessed>=1.19.0->inquirer<5.0,>=2.10.0->lightning>=2.0.1->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (0.2.6)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /opt/conda/lib/python3.10/site-packages (from numba>=0.51.0->librosa>=0.6.0->torch_audiomentations>=0.11.0->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (0.40.1)
# Requirement already satisfied: appdirs>=1.3.0 in /opt/conda/lib/python3.10/site-packages (from pooch<1.7,>=1.0->librosa>=0.6.0->torch_audiomentations>=0.11.0->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (1.4.4)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /opt/conda/lib/python3.10/site-packages (from ruamel.yaml<=0.17.28,>=0.17.8->hyperpyyaml->speechbrain>=0.5.14->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (0.2.7)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.10/site-packages (from sqlalchemy>=1.3.0->optuna>=1.4->pyannote.pipeline>=2.3->pyannote.audio@ git+https://github.com/pyannote/pyannote-audio@11b56a137a578db9335efc00298f6ec1932e6317->whisperx==3.1.1) (2.0.2)
# Building wheels for collected packages: whisperx, pyannote.audio
#   Building wheel for whisperx (setup.py) ... done
#   Created wheel for whisperx: filename=whisperx-3.1.1-py3-none-any.whl size=30782 sha256=75272d4bbfd54aaf6e475807adca8eb94171c433674f2c756b57a1a37b0542cf
#   Stored in directory: /tmp/pip-ephem-wheel-cache-gj6k59lw/wheels/27/fb/53/682b85073a466f1866910d7257233e53b0cc126ab50e7c5373
#   Building wheel for pyannote.audio (setup.py) ... done
#   Created wheel for pyannote.audio: filename=pyannote.audio-2.1.1-py2.py3-none-any.whl size=400156 sha256=59f7a292df5847ed6dc54b9c1479134c8104a4a97b384e3185ef1b4892515e59
#   Stored in directory: /root/.cache/pip/wheels/1e/f2/4f/ffd6fd3ec96beb935d2f006678342850a3527eca2a9e522df3
# Successfully built whisperx pyannote.audio
# Installing collected packages: python-editor, primePy, av, setuptools, ruamel.yaml, python-multipart, ordered-set, humanfriendly, ffmpeg-python, ctranslate2, readchar, pyannote.core, hyperpyyaml, deepdiff, dateutils, croniter, coloredlogs, starsessions, pytorch_metric_learning, onnxruntime, inquirer, asteroid-filterbanks, torch-pitch-shift, speechbrain, pyannote.database, lightning-cloud, faster-whisper, torch_audiomentations, pyannote.pipeline, pyannote.metrics, lightning, pyannote.audio, whisperx
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 59.8.0
#     Uninstalling setuptools-59.8.0:
#       Successfully uninstalled setuptools-59.8.0
#   Attempting uninstall: ruamel.yaml
#     Found existing installation: ruamel.yaml 0.17.32
#     Uninstalling ruamel.yaml-0.17.32:
#       Successfully uninstalled ruamel.yaml-0.17.32
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opentelemetry-api 1.18.0 requires importlib-metadata~=6.0.0, but you have importlib-metadata 6.7.0 which is incompatible.
# pymc3 3.11.5 requires numpy<1.22.2,>=1.15.0, but you have numpy 1.23.5 which is incompatible.
# pymc3 3.11.5 requires scipy<1.8.0,>=1.7.3, but you have scipy 1.11.1 which is incompatible.
# ...
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4<6.0,>=4.8.0->lightning>=2.0.1->pyannote-audio) (2.3.2.post1)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=1.0->soundfile>=0.12.1->pyannote-audio) (2.21)
# Requirement already satisfied: ordered-set<4.2.0,>=4.0.2 in /opt/conda/lib/python3.10/site-packages (from deepdiff<8.0,>=5.7.0->lightning>=2.0.1->pyannote-audio) (4.1.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/conda/lib/python3.10/site-packages (from fsspec->huggingface-hub>=0.13.0->pyannote-audio) (3.8.4)
# Requirement already satisfied: blessed>=1.19.0 in /opt/conda/lib/python3.10/site-packages (from inquirer<5.0,>=2.10.0->lightning>=2.0.1->pyannote-audio) (1.20.0)
# Requirement already satisfied: python-editor>=1.0.4 in /opt/conda/lib/python3.10/site-packages (from inquirer<5.0,>=2.10.0->lightning>=2.0.1->pyannote-audio) (1.0.4)
# Requirement already satisfied: readchar>=3.0.6 in /opt/conda/lib/python3.10/site-packages (from inquirer<5.0,>=2.10.0->lightning>=2.0.1->pyannote-audio) (4.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from Jinja2<5.0->lightning>=2.0.1->pyannote-audio) (2.1.3)
# Requirement already satisfied: audioread>=2.1.9 in /opt/conda/lib/python3.10/site-packages (from librosa>=0.6.0->torch-audiomentations>=0.11.0->pyannote-audio) (3.0.0)
# Requirement already satisfied: decorator>=4.3.0 in /opt/conda/lib/python3.10/site-packages (from librosa>=0.6.0->torch-audiomentations>=0.11.0->pyannote-audio) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in /opt/conda/lib/python3.10/site-packages (from librosa>=0.6.0->torch-audiomentations>=0.11.0->pyannote-audio) (0.57.1)
# Requirement already satisfied: pooch>=1.0 in /opt/conda/lib/python3.10/site-packages (from librosa>=0.6.0->torch-audiomentations>=0.11.0->pyannote-audio) (1.6.0)
# Requirement already satisfied: soxr>=0.3.2 in /opt/conda/lib/python3.10/site-packages (from librosa>=0.6.0->torch-audiomentations>=0.11.0->pyannote-audio) (0.3.5)
# Requirement already satisfied: lazy-loader>=0.1 in /opt/conda/lib/python3.10/site-packages (from librosa>=0.6.0->torch-audiomentations>=0.11.0->pyannote-audio) (0.2)
# Requirement already satisfied: msgpack>=1.0 in /opt/conda/lib/python3.10/site-packages (from librosa>=0.6.0->torch-audiomentations>=0.11.0->pyannote-audio) (1.0.5)
# Requirement already satisfied: pyjwt in /opt/conda/lib/python3.10/site-packages (from lightning-cloud>=0.5.37->lightning>=2.0.1->pyannote-audio) (2.7.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->pyannote-audio) (0.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote-audio) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote-audio) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote-audio) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote-audio) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote-audio) (9.5.0)
# Requirement already satisfied: alembic>=1.5.0 in /opt/conda/lib/python3.10/site-packages (from optuna>=1.4->pyannote.pipeline>=2.3->pyannote-audio) (1.11.1)
# Requirement already satisfied: cmaes>=0.9.1 in /opt/conda/lib/python3.10/site-packages (from optuna>=1.4->pyannote.pipeline>=2.3->pyannote-audio) (0.9.1)
# Requirement already satisfied: colorlog in /opt/conda/lib/python3.10/site-packages (from optuna>=1.4->pyannote.pipeline>=2.3->pyannote-audio) (6.7.0)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /opt/conda/lib/python3.10/site-packages (from optuna>=1.4->pyannote.pipeline>=2.3->pyannote-audio) (2.0.17)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.17.1->pyannote.metrics>=3.2->pyannote-audio) (3.1.0)
# Requirement already satisfied: anyio<5,>=3.4.0 in /opt/conda/lib/python3.10/site-packages (from starlette->lightning>=2.0.1->pyannote-audio) (3.7.0)
# Requirement already satisfied: itsdangerous<3.0.0,>=2.0.1 in /opt/conda/lib/python3.10/site-packages (from starsessions<2.0,>=1.2.1->lightning>=2.0.1->pyannote-audio) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy>=1.1->pyannote.metrics>=3.2->pyannote-audio) (1.3.0)
# Requirement already satisfied: primePy>=1.3 in /opt/conda/lib/python3.10/site-packages (from torch-pitch-shift>=1.2.2->torch-audiomentations>=0.11.0->pyannote-audio) (1.3)
# Requirement already satisfied: colorama<0.5.0,>=0.4.3 in /opt/conda/lib/python3.10/site-packages (from typer[all]>=0.2.1->pyannote.database>=5.0.1->pyannote-audio) (0.4.6)
# Requirement already satisfied: shellingham<2.0.0,>=1.3.0 in /opt/conda/lib/python3.10/site-packages (from typer[all]>=0.2.1->pyannote.database>=5.0.1->pyannote-audio) (1.5.1)
# Requirement already satisfied: h11>=0.8 in /opt/conda/lib/python3.10/site-packages (from uvicorn<2.0->lightning>=2.0.1->pyannote-audio) (0.14.0)
# Requirement already satisfied: ruamel.yaml<=0.17.28,>=0.17.8 in /opt/conda/lib/python3.10/site-packages (from hyperpyyaml->speechbrain>=0.5.14->pyannote-audio) (0.17.28)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->huggingface-hub>=0.13.0->pyannote-audio) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->huggingface-hub>=0.13.0->pyannote-audio) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->huggingface-hub>=0.13.0->pyannote-audio) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->huggingface-hub>=0.13.0->pyannote-audio) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->huggingface-hub>=0.13.0->pyannote-audio) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->huggingface-hub>=0.13.0->pyannote-audio) (1.3.1)
# Requirement already satisfied: Mako in /opt/conda/lib/python3.10/site-packages (from alembic>=1.5.0->optuna>=1.4->pyannote.pipeline>=2.3->pyannote-audio) (1.2.4)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.10/site-packages (from anyio<5,>=3.4.0->starlette->lightning>=2.0.1->pyannote-audio) (1.3.0)
# Requirement already satisfied: exceptiongroup in /opt/conda/lib/python3.10/site-packages (from anyio<5,>=3.4.0->starlette->lightning>=2.0.1->pyannote-audio) (1.1.1)
# Requirement already satisfied: wcwidth>=0.1.4 in /opt/conda/lib/python3.10/site-packages (from blessed>=1.19.0->inquirer<5.0,>=2.10.0->lightning>=2.0.1->pyannote-audio) (0.2.6)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /opt/conda/lib/python3.10/site-packages (from numba>=0.51.0->librosa>=0.6.0->torch-audiomentations>=0.11.0->pyannote-audio) (0.40.1)
# Requirement already satisfied: appdirs>=1.3.0 in /opt/conda/lib/python3.10/site-packages (from pooch>=1.0->librosa>=0.6.0->torch-audiomentations>=0.11.0->pyannote-audio) (1.4.4)
# Requirement already satisfied: setuptools>=41.0 in /opt/conda/lib/python3.10/site-packages (from readchar>=3.0.6->inquirer<5.0,>=2.10.0->lightning>=2.0.1->pyannote-audio) (65.5.1)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /opt/conda/lib/python3.10/site-packages (from ruamel.yaml<=0.17.28,>=0.17.8->hyperpyyaml->speechbrain>=0.5.14->pyannote-audio) (0.2.7)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.10/site-packages (from sqlalchemy>=1.3.0->optuna>=1.4->pyannote.pipeline>=2.3->pyannote-audio) (2.0.2)
# Building wheels for collected packages: youtokentome
#   Building wheel for youtokentome (setup.py) ... done
#   Created wheel for youtokentome: filename=youtokentome-1.0.6-cp310-cp310-linux_x86_64.whl size=193372 sha256=c90d008c4d53c3be155048c8e6effab0f3f7209fa95e1ef518b9252b55774438
#   Stored in directory: /root/.cache/pip/wheels/df/85/f8/301d2ba45f43f30bed2fe413efa760bc726b8b660ed9c2900c
# Successfully built youtokentome
# Installing collected packages: youtokentome, editdistance, pandas, inflect, transformers
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.30.2
#     Uninstalling transformers-4.30.2:
#       Successfully uninstalled transformers-4.30.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf 23.6.1 requires cupy-cuda11x>=12.0.0, which is not installed.
# cuml 23.6.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# dask-cudf 23.6.1 requires cupy-cuda11x>=12.0.0, which is not installed.
# beatrix-jupyterlab 2023.621.222118 requires jupyter-server~=1.16, but you have jupyter-server 2.6.0 which is incompatible.
# cudf 23.6.1 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.1.0 which is incompatible.
# cudf 23.6.1 requires protobuf<4.22,>=4.21.6, but you have protobuf 3.20.3 which is incompatible.
# cuml 23.6.0 requires dask==2023.3.2, but you have dask 2023.7.0 which is incompatible.
# dask-cuda 23.6.0 requires dask==2023.3.2, but you have dask 2023.7.0 which is incompatible.
# dask-cuda 23.6.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.1.0 which is incompatible.
# dask-cudf 23.6.1 requires dask==2023.3.2, but you have dask 2023.7.0 which is incompatible.
# dask-cudf 23.6.1 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.1.0 which is incompatible.
# featuretools 1.26.0 requires pandas<2.0.0,>=1.5.0, but you have pandas 2.1.0 which is incompatible.
# momepy 0.6.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# pymc3 3.11.5 requires numpy<1.22.2,>=1.15.0, but you have numpy 1.23.5 which is incompatible.
# pymc3 3.11.5 requires scipy<1.8.0,>=1.7.3, but you have scipy 1.11.1 which is incompatible.
# raft-dask 23.6.2 requires dask==2023.3.2, but you have dask 2023.7.0 which is incompatible.
# woodwork 0.24.0 requires pandas<2.0.0,>=1.4.3, but you have pandas 2.1.0 which is incompatible.
# ydata-profiling 4.3.1 requires pandas!=1.4.0,<2.1,>1.1, but you have pandas 2.1.0 which is incompatible.
# ydata-profiling 4.3.1 requires scipy<1.11,>=1.4.1, but you have scipy 1.11.1 which is incompatible.
# Successfully installed editdistance-0.6.2 inflect-7.0.0 pandas-2.0.2 transformers-4.33.0 youtokentome-1.0.6
# Requirement already satisfied: pytorch-lightning in /opt/conda/lib/python3.10/site-packages (2.0.4)
# Collecting pytorch-lightning
#   Downloading pytorch_lightning-2.0.8-py3-none-any.whl (727 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 727.0/727.0 kB 14.0 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: numpy>=1.17.2 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (1.23.5)
# Requirement already satisfied: torch>=1.11.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (2.0.0)
# Requirement already satisfied: tqdm>=4.57.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (4.65.0)
# Requirement already satisfied: PyYAML>=5.4 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (6.0.1)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (2023.6.0)
# Requirement already satisfied: torchmetrics>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (1.0.0)
# Requirement already satisfied: packaging>=17.1 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (21.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (4.6.3)
# Requirement already satisfied: lightning-utilities>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (0.9.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from fsspec[http]>2021.06.0->pytorch-lightning) (2.31.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]>2021.06.0->pytorch-lightning) (3.8.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=17.1->pytorch-lightning) (3.0.9)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.11.0->pytorch-lightning) (3.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.11.0->pytorch-lightning) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.11.0->pytorch-lightning) (3.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.11.0->pytorch-lightning) (3.1.2)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (3.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.11.0->pytorch-lightning) (2.1.3)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning) (2023.5.7)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.11.0->pytorch-lightning) (1.3.0)
# Installing collected packages: pytorch-lightning
#   Attempting uninstall: pytorch-lightning
#     Found existing installation: pytorch-lightning 2.0.4
#     Uninstalling pytorch-lightning-2.0.4:
#       Successfully uninstalled pytorch-lightning-2.0.4
# Successfully installed pytorch-lightning-2.0.8

# %% [markdown]
# ## 下载视频，你也可以选择上传文件

# %%
import yt_dlp
yt_url = 'https://www.youtube.com/watch?v=tgdJkAx3fJM'
ydl_opts = {
    'format': 'm4a/bestaudio/best',
    'outtmpl': '%(id)s.%(ext)s',
    'postprocessors': [{
        'key': 'FFmpegExtractAudio',
        'preferredcodec': 'wav',
    }],
}

with yt_dlp.YoutubeDL(ydl_opts) as ydl:
    error_code = ydl.download(yt_url)
    video_info = ydl.extract_info(yt_url, download=False)
    file_name = f"{video_info['id']}.wav"
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=tgdJkAx3fJM
# [youtube] tgdJkAx3fJM: Downloading webpage
# [youtube] tgdJkAx3fJM: Downloading ios player API JSON
# [youtube] tgdJkAx3fJM: Downloading android player API JSON
# [youtube] tgdJkAx3fJM: Downloading m3u8 information
# [info] tgdJkAx3fJM: Downloading 1 format(s): 140
# [download] Destination: tgdJkAx3fJM.m4a
# [download] 100% of    7.41MiB in 00:00:00 at 21.17MiB/s
# [FixupM4a] Correcting container of "tgdJkAx3fJM.m4a"
# [ExtractAudio] Destination: tgdJkAx3fJM.wav
# Deleting original file tgdJkAx3fJM.m4a (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=tgdJkAx3fJM
# [youtube] tgdJkAx3fJM: Downloading webpage
# [youtube] tgdJkAx3fJM: Downloading ios player API JSON
# [youtube] tgdJkAx3fJM: Downloading android player API JSON
# [youtube] tgdJkAx3fJM: Downloading m3u8 information

# %% [markdown]
# ## 对工作目录下的最新音/视频文件进行预处理

# %%
import os
import demucs.separate
import shlex

file_extension = ['.mp4', '.wav']
allowed_files = [file for file in os.listdir() if any(file.lower().endswith(ext) for ext in file_extension)]
input_file = max(allowed_files, key=lambda file: os.path.getctime(file))

demucs.separate.main(shlex.split(f'-n htdemucs --two-stems=vocals "{input_file}" -o "temp_outputs"'))
input_file = os.path.join(
        "temp_outputs", "htdemucs", os.path.basename(input_file[:-4]), "vocals.wav")

audio_file = "audio_16k.wav"
# !rm -rf {audio_file}
# !ffmpeg -i {input_file} -ac 1 -ar 16000 {audio_file}
# Out:
# Downloading: "https://dl.fbaipublicfiles.com/demucs/hybrid_transformer/955717e8-8726e21a.th" to /root/.cache/torch/hub/checkpoints/955717e8-8726e21a.th
# 100%|██████████| 80.2M/80.2M [00:00<00:00, 146MB/s]
# Selected model is a bag of 1 models. You will see that many progress bars per track.
# Separated tracks will be stored in /kaggle/working/temp_outputs/htdemucs
# Separating track tgdJkAx3fJM.wav
# 100%|██████████████████████████████████████████████| 485.54999999999995/485.54999999999995 [00:24<00:00, 19.52seconds/s]
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Guessed Channel Layout for Input Stream #0.0 : stereo
# Input #0, wav, from 'temp_outputs/htdemucs/tgdJkAx3fJM/vocals.wav':
#   Duration: 00:07:59.96, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'audio_16k.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_s16le
# size=   14999kB time=00:07:59.95 bitrate= 256.0kbits/s speed= 934x
# video:0kB audio:14999kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000508%

# %% [markdown]
# ## 语音转录&对齐

# %%
from faster_whisper import WhisperModel
import whisperx
import torch

device = "cuda"
compute_type = "float16"
whisper_model = "medium"

model = WhisperModel(whisper_model, device=device, compute_type=compute_type)
segments, info = model.transcribe(audio_file, beam_size=1, word_timestamps=False,vad_filter=True, vad_parameters=dict(min_silence_duration_ms=500))

whisper_results = []

for segment in segments:
  print("[%.2fs -> %.2fs] 「%s」\n" % (segment.start, segment.end, segment.text))
  whisper_results.append(segment._asdict())


del model
torch.cuda.empty_cache()

alignment_model, metadata = whisperx.load_align_model(language_code=info.language, device=device)
result_aligned = whisperx.align(whisper_results, alignment_model, metadata, audio_file, device)
word_ts = result_aligned["segments"]

del alignment_model
torch.cuda.empty_cache()
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# [NeMo W 2023-09-05 05:17:58 transformer_bpe_models:59] Could not import NeMo NLP collection which is required for speech translation model.
# Downloading (…)90c7f7fb/config.json:   0%|          | 0.00/2.26k [00:00<?, ?B/s]
# Downloading (…)7f7fb/vocabulary.txt:   0%|          | 0.00/460k [00:00<?, ?B/s]
# Downloading (…)7f7fb/tokenizer.json:   0%|          | 0.00/2.20M [00:00<?, ?B/s]
# Downloading model.bin:   0%|          | 0.00/1.53G [00:00<?, ?B/s]
# [0.94s -> 3.60s] 「計算式プラグインはやっぱり便利ですか?」
#
# [3.60s -> 8.42s] 「便利ですね。やっぱり元々のKintonの計算フィールドって結局、」
#
# [8.42s -> 12.52s] 「文字列1行と計算フィールドにしか入らないんですけど。」
#
# [12.52s -> 16.04s] 「はい、もうKintonさんある。」
#
# [16.04s -> 19.16s] 「今日はですね、後ろまたなべちゃんを呼んで、」
#
# [19.16s -> 23.10s] 「備品管理のKinton活用事例っていうのをご紹介していきたいなと思います。」
#
# [23.10s -> 29.68s] 「備品管理だけじゃなくて、僕らが最近教えている計算式プラグインを使った事例となりますので、」
#
# [29.68s -> 33.78s] 「こんなこともできるんだよっていうのを参考になればいいかなと思っております。」
#
# [33.78s -> 38.48s] 「うちのなべちゃんはですね、クルーデータとか、計算式プラグインをひたすら使いまくってますから、」
#
# [38.48s -> 42.16s] 「それ実際にお客さんの導入事例としてあるということだったので、」
#
# [42.16s -> 44.82s] 「持ち込み企画として動画に撮っております。」
#
# [44.82s -> 49.46s] 「ということで、じゃあなべちゃん、まずは実際に概要の部分だけ共有してもらった上で、」
#
# [49.46s -> 52.40s] 「画面共有してデモを見せる順番でお願いします。」
#
# [52.40s -> 53.94s] 「アプリの概要ですね。」
#
# [53.94s -> 58.18s] 「わかりました。アプリ的には、社内の備品管理っていうところを目指しています。」
#
# [58.18s -> 62.48s] 「外国人向けの日本語教育されている会社さんの事例で作ったやつで、」
#
# [62.48s -> 67.18s] 「その日本語のテティスト周り、同じテティストも10冊ぐらい持っていたとして、」
#
# [67.18s -> 70.12s] 「その10冊それぞれに番号を付けて管理しています。」
#
# [70.12s -> 74.66s] 「今誰が借りてるっていうのがわかるようにしてほしいっていう話があったので、」
#
# [74.66s -> 79.40s] 「それで作ったアプリっていうのを今回、事例として中身は少し入れ替えたり、」
#
# [79.40s -> 83.34s] 「中のレコードとかは僕らがオリジナルで作った状態にはなるんですけど、」
#
# [83.34s -> 86.64s] 「それをお見せできればと思います。」
#
# [86.64s -> 91.18s] 「いわゆるそのボールペンとか鉛筆みたいな消耗品の管理じゃなくて、」
#
# [91.18s -> 95.12s] 「消耗しないものでね、本とかマイメーター、その教科書みたいな感じで、」
#
# [95.12s -> 100.92s] 「一つ一つ固有で管理をしていて、例えば教科書のAは誰が入れてるっていうのを」
#
# [100.92s -> 102.96s] 「しかしたいって言った目的のアプリだね。」
#
# [102.96s -> 106.52s] 「そうです。工具とかでも使えるかなと思ってるんですよ。」
#
# [106.52s -> 109.80s] 「確かにOKです。じゃあちょっとお願いします。」
#
# [109.80s -> 112.80s] 「じゃあ画面共有して見せていきます。」
#
# [112.80s -> 116.80s] 「まず、会社の備品っていうのはご所属に適当に作ってるだけで、」
#
# [116.80s -> 119.54s] 「実際もっと種類が多くても大丈夫です。」
#
# [119.54s -> 123.44s] 「例えば、一番のこのケーブルを借りようとした時は、」
#
# [123.44s -> 126.24s] 「レコード、ちょうど今借りた状態になってますね。」
#
# [126.24s -> 128.24s] 「一回ちょっと返したってことにして、」
#
# [128.24s -> 132.68s] 「借りる時、プラスで量を増やしていただくと、こういうふうに作られてきます。」
#
# [132.68s -> 137.96s] 「これで保存をかけてもらったら、僕が今借りてる状態ですっていうのがわかります。」
#
# [137.96s -> 141.16s] 「一覧の方に戻っていくと、僕が借りてるってことで、」
#
# [141.16s -> 143.96s] 「私が借りてるものっていうリストに出てきます。」
#
# [143.96s -> 148.20s] 「他の方にとっては、全体の中の貸し出し可能なやつっていうことで、」
#
# [148.20s -> 150.36s] 「さっきもともと5種類あったんですけど、」
#
# [150.36s -> 153.04s] 「5種類のうち2つちょっと今人が借りてるので、」
#
# [153.04s -> 155.40s] 「残り3つが使える状態ですよ。」
#
# [155.40s -> 158.04s] 「さらに貸し出し中の備品っていうところでは、」
#
# [158.04s -> 161.14s] 「誰が借りてますよっていうのが見れるようになってます。」
#
# [161.14s -> 164.84s] 「これは同じ品名HDMIケーブルで1メートルとなってるけど、」
#
# [164.84s -> 166.32s] 「備品管理番号は違うから、」
#
# [166.32s -> 168.88s] 「要はHDMIケーブルが2つあるんだけど、」
#
# [168.88s -> 172.48s] 「それぞれ別個で1個ずつ管理してるってことだよね。」
#
# [172.48s -> 177.98s] 「そうです。返すときは、返した日っていうのを入れてもらって、」
#
# [177.98s -> 180.30s] 「保存書きでもらったら大丈夫です。」
#
# [180.30s -> 184.10s] 「こうなると、今一応僕が借りてる状態じゃなくなってるので、」
#
# [184.10s -> 186.20s] 「私が借りてるものっていうのにはなくない。」
#
# [186.20s -> 188.60s] 「だいたいこういうなんか備品系って、」
#
# [188.60s -> 191.20s] 「最後返ってきたとき誰かがチェックすると思うんですよ。」
#
# [191.20s -> 193.30s] 「壊れてないかとか、破れてないかとか。」
#
# [193.30s -> 196.96s] 「なので、管理部チェック待ち備品っていうところに入っていきます。」
#
# [196.96s -> 199.70s] 「管理部の方がチェックしてもらって、」
#
# [199.70s -> 201.70s] 「壊れてないよっていうのを確認してもらったら、」
#
# [201.70s -> 203.50s] 「確認っていうところにチェック入れてください。」
#
# [203.50s -> 206.10s] 「そしたら、チェック待ちが終わって、」
#
# [206.10s -> 210.10s] 「貸出可能な備品リストの方にまた戻っていくと。」
#
# [210.10s -> 211.40s] 「こういうふうになってます。」
#
# [211.40s -> 214.54s] 「一般的なよくある備品管理の仕組みであって、」
#
# [214.54s -> 216.44s] 「ちょっとこれはかなり簡単に作ってるけど、」
#
# [216.44s -> 219.74s] 「単純にテーブルで借りたら、テーブルを追加して、」
#
# [219.74s -> 221.24s] 「借りた日付を入れると。」
#
# [221.24s -> 224.88s] 「再返却したら、そのテーブルに対して返却費を入れてあげて、」
#
# [224.88s -> 228.38s] 「最終的に管理部が問題ないよってチェック付けたら、」
#
# [228.38s -> 230.84s] 「一覧で表示制御を空けているっていう感じだよね。」
#
# [230.84s -> 231.54s] 「はい。」
#
# [231.54s -> 235.88s] 「今回は、この計算式プラグインをどこで使っているか教えてもらっていい?」
#
# [235.88s -> 240.74s] 「元々の作りとしては、テーブルの最後のところに追加しても、」
#
# [240.74s -> 243.04s] 「最後今誰が借りているのっていうことかは、」
#
# [243.04s -> 245.34s] 「自分で入力しないといけなかったんですよ。」
#
# [245.34s -> 247.88s] 「だんだん伸びてくると、やっぱり下の方に行って、」
#
# [247.88s -> 251.14s] 「こっちにも入れてって、なかなかやってくれなくなったりもするので、」
#
# [251.14s -> 254.34s] 「ここらへん自動化したいなっていう気持ちがあって、」
#
# [254.34s -> 256.64s] 「計算してプラグインの中身としては、」
#
# [256.64s -> 259.44s] 「テーブルの一番下の量の内容っていうのを、」
#
# [259.44s -> 261.74s] 「ここに複製するようにしています。」
#
# [261.74s -> 265.04s] 「例えば、こうするとこういうふうに変わっていくのに。」
#
# [265.04s -> 265.94s] 「分かりましたかね?」
#
# [265.94s -> 268.88s] 「この一番下の今日、小川晴くって入れたものが、」
#
# [268.88s -> 273.14s] 「自動で、ここのユーザー選択フィールドに反映するようになってるんですよ。」
#
# [273.14s -> 274.98s] 「これは均等に標準機能じゃできなくて、」
#
# [274.98s -> 278.64s] 「テーブル内にある情報をテーブル外に移すっていうのは、」
#
# [278.64s -> 280.28s] 「サム関数とかはできますけど、」
#
# [280.28s -> 281.78s] 「こういった処理はできないんですね。」
#
# [281.78s -> 285.58s] 「もともとは、この最後に借りた人っていうところを基準に、」
#
# [285.58s -> 288.58s] 「さっきの一覧でいろいろ表示制御をしてるわけなんですけど、」
#
# [288.58s -> 292.68s] 「一番下にテーブル入力して、さらに最後に借りた人に手入力するっていうのは、」
#
# [292.68s -> 294.18s] 「面倒されてるっていうことだったので、」
#
# [294.18s -> 295.98s] 「計算式プラグインを使ってあげると、」
#
# [295.98s -> 298.58s] 「一番下の行に入っているユーザーを、」
#
# [298.58s -> 301.18s] 「最後に借りた人に自動で入ってくるようにするっていうか、」
#
# [301.18s -> 303.38s] 「制御して自動化したっていう事例だよね。」
#
# [303.38s -> 304.28s] 「そうですね。」
#
# [304.28s -> 306.18s] 「計算式プラグインの事例ですね。」
#
# [306.18s -> 309.98s] 「ということで、今回はかなり簡単な事例ではあるんですけど、」
#
# [309.98s -> 313.48s] 「実際に備品の価値出し管理アプリの均等事例となります。」
#
# [313.48s -> 314.78s] 「計算式プラグインを使うと、」
#
# [314.78s -> 317.08s] 「こういう細かいこともできるよっていうところで、」
#
# [317.08s -> 320.38s] 「僕たちは計算式プラグイン、最近かなり対応しておりますので、」
#
# [320.38s -> 322.78s] 「ちょっとした機能とかを盛り込みたいという時には、」
#
# [322.78s -> 324.98s] 「こういった風にサクッとできたりもしますので、」
#
# [324.98s -> 326.58s] 「ぜひ参考にしてみてください。」
#
# [326.58s -> 328.78s] 「せっかくからちょっと裏側の設定画面見せようか、」
#
# [328.78s -> 329.68s] 「計算式プラグイン。」
#
# [329.68s -> 331.68s] 「こんな感じになってます。」
#
# [331.68s -> 335.48s] 「このフィールドに、こういう風な計算式に従って、」
#
# [335.48s -> 337.38s] 「データを入れろというのを書いてます。」
#
# [337.38s -> 342.18s] 「これはテーブルの一番下の行のデータを取得するっていう計算式かな。」
#
# [342.18s -> 345.98s] 「そうです。ラストがテーブルの一番下の行っていうので、」
#
# [345.98s -> 347.38s] 「セットコードっていうのが、」
#
# [347.38s -> 350.98s] 「ユーザー選択フィールドにデータを入れたいっていう時に使うやつです。」
#
# [350.98s -> 353.68s] 「それをフィールドコードの最後の行の指名っていう、」
#
# [353.68s -> 356.18s] 「さっきのユーザー選択フィールドに指定してあげることによって、」
#
# [356.18s -> 359.68s] 「テーブルの一番下のユーザー選択の情報を引っこ抜いてきて、」
#
# [359.68s -> 363.58s] 「最後の行の指名っていうユーザー選択フィールドに反映するようにしてるっていう計算式だね。」
#
# [363.58s -> 364.18s] 「そうです。」
#
# [364.18s -> 365.48s] 「この下のやつも同じかな。」
#
# [365.48s -> 369.78s] 「最新の確認状態ってことで、いわゆる管理部が最後に確認したかどうかっていうのも、」
#
# [369.78s -> 374.18s] 「テーブル外に持ってきたようで、だから同じような計算式を組んで設定してあげるという。」
#
# [374.18s -> 378.88s] 「そうですね。こちらとチェックボックスのフィールドに計算式が使えるようになっています。」
#
# [378.88s -> 382.38s] 「なるほど。という感じで計算式プラグインはやっぱり便利ですか?」
#
# [382.38s -> 386.88s] 「便利ですね。やっぱり元々のKintonの計算フィールドって、」
#
# [386.88s -> 390.88s] 「結局は文字列一行と計算フィールドにしか入らないんですけど、」
#
# [390.88s -> 395.18s] 「それをユーザー選択だったり、チェックボックスだったり、あるいはドロップダウンとか、」
#
# [395.18s -> 397.38s] 「そういうところにも使えるようになりますし、」
#
# [397.38s -> 401.38s] 「計算式の中身にユーザー選択フィールドの中身って使えないんですよ。」
#
# [401.38s -> 402.18s] 「ないね。」
#
# [402.18s -> 406.28s] 「カレンダー型の一覧とか作ろうとした後にユーザー選択と何かこう、」
#
# [406.28s -> 411.88s] 「文字列一行を結合しようとしたら、ユーザー選択使えないじゃんってなって止まるってよくあるんですけど、」
#
# [411.88s -> 413.38s] 「それも使えるようになります。」
#
# [413.38s -> 414.78s] 「確かにね。ということで、」
#
# [414.78s -> 417.78s] 「もっともっとは計算式プラグインは鍋ちゃんが見つけてきたんだよね。」
#
# [417.78s -> 422.08s] 「鍋ちゃんが見つけてきて、ペパコミ内でこれいいねみたいな感じで、」
#
# [422.08s -> 424.88s] 「結構導入率が高くなっているという感じで。」
#
# [424.88s -> 427.41s] 「もう一人毎日来ましたもんね。」
#
# [427.41s -> 430.31s] 「そうそうそう。これやばいねみたいな。」
#
# [430.31s -> 435.51s] 「今回は僕たちが予行して、計算式プラグインに突入した事例ということで、」
#
# [435.51s -> 438.81s] 「面白いかなと思って動画に撮らせていただきました。」
#
# [438.81s -> 442.11s] 「ということで今日はね、うちの担当の鍋ちゃんも呼んで、」
#
# [442.11s -> 443.71s] 「備品管理のデモということで、」
#
# [443.71s -> 447.31s] 「実際お客様にやった計算式プラグインを使った事例をご紹介させていただきました。」
#
# [447.31s -> 450.61s] 「参考になりましたら、ぜひチャンネル登録とかいいねをお待ちしております。」
#
# [450.61s -> 452.41s] 「他にもこんなことをやってほしいとかあればですね、」
#
# [452.41s -> 456.01s] 「コメントいただければなるべく対応するようにしますので、よろしくお願いします。」
#
# [456.01s -> 457.91s] 「ということで今日は以上となります。」
#
# [457.91s -> 459.31s] 「これからも近藤大学大学の話をしていきまして、」
#
# [459.31s -> 460.61s] 「チャンネル登録もぜひ本日もありがとうございました。」
#
# [460.61s -> 463.61s] 「また近藤大学の話をしましょう。バイバーイ。」
# Downloading (…)rocessor_config.json:   0%|          | 0.00/158 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.57k [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/29.3k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/85.0 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/1.27G [00:00<?, ?B/s]

# %% [markdown]
# ## Nemo分类

# %%
import os
import json
import wget
from omegaconf import OmegaConf
from nemo.collections.asr.models.msdd_models import ClusteringDiarizer
import torch

diarize_manifest = {
  'audio_filepath': f'./{audio_file}',
  'offset': 0,
  'duration':  None,
  'label': "infer",
  'text': "-",
  'num_speakers': None,
  'rttm_filepath': f'./diarized/pred_rttms/audio_16k.rttm',
  'uniq_id': ""
}

if not os.path.exists('./manifest.json'):
  with open('./manifest.json', 'w') as f:
    f.write(json.dumps(diarize_manifest))

MODEL_CONFIG = os.path.join('./','diar_infer_meeting.yaml')
if not os.path.exists(MODEL_CONFIG):
    config_url = "https://raw.githubusercontent.com/NVIDIA/NeMo/main/examples/speaker_tasks/diarization/conf/inference/diar_infer_meeting.yaml"
    MODEL_CONFIG = wget.download(config_url, './')

config = OmegaConf.load(MODEL_CONFIG)
config.num_workers = 4
config.batch_size = 32

config.diarizer.manifest_filepath = './manifest.json'
config.diarizer.out_dir = os.path.join('./', 'diarized')
config.diarizer.speaker_embeddings.model_path = 'titanet_large'
config.diarizer.speaker_embeddings.parameters.window_length_in_sec = [1.5, 1.0, 0.5]
config.diarizer.speaker_embeddings.parameters.shift_length_in_sec = [0.75, 0.5, 0.25]
config.diarizer.speaker_embeddings.parameters.multiscale_weights = [0.33, 0.33, 0.33]
config.diarizer.speaker_embeddings.parameters.save_embeddings = False

config.diarizer.ignore_overlap = False
config.diarizer.oracle_vad = False
config.diarizer.collar = 0.25


config.diarizer.vad.model_path = 'vad_multilingual_marblenet'
config.diarizer.oracle_vad = False

model = ClusteringDiarizer(cfg=config)
model.diarize()

del model
torch.cuda.empty_cache()
# Out:
# [NeMo I 2023-09-05 05:19:29 clustering_diarizer:127] Loading pretrained vad_multilingual_marblenet model from NGC
# [NeMo I 2023-09-05 05:19:29 cloud:68] Downloading from: https://api.ngc.nvidia.com/v2/models/nvidia/nemo/vad_multilingual_marblenet/versions/1.10.0/files/vad_multilingual_marblenet.nemo to /root/.cache/torch/NeMo/NeMo_1.21.0rc0/vad_multilingual_marblenet/670f425c7f186060b7a7268ba6dfacb2/vad_multilingual_marblenet.nemo
# [NeMo I 2023-09-05 05:19:30 common:913] Instantiating model from pre-trained checkpoint
# [NeMo W 2023-09-05 05:19:30 modelPT:161] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     manifest_filepath: /manifests/ami_train_0.63.json,/manifests/freesound_background_train.json,/manifests/freesound_laughter_train.json,/manifests/fisher_2004_background.json,/manifests/fisher_2004_speech_sampled.json,/manifests/google_train_manifest.json,/manifests/icsi_all_0.63.json,/manifests/musan_freesound_train.json,/manifests/musan_music_train.json,/manifests/musan_soundbible_train.json,/manifests/mandarin_train_sample.json,/manifests/german_train_sample.json,/manifests/spanish_train_sample.json,/manifests/french_train_sample.json,/manifests/russian_train_sample.json
#     sample_rate: 16000
#     labels:
#     - background
#     - speech
#     batch_size: 256
#     shuffle: true
#     is_tarred: false
#     tarred_audio_filepaths: null
#     tarred_shard_strategy: scatter
#     augmentor:
#       shift:
#         prob: 0.5
#         min_shift_ms: -10.0
#         max_shift_ms: 10.0
#       white_noise:
#         prob: 0.5
#         min_level: -90
#         max_level: -46
#         norm: true
#       noise:
#         prob: 0.5
#         manifest_path: /manifests/noise_0_1_musan_fs.json
#         min_snr_db: 0
#         max_snr_db: 30
#         max_gain_db: 300.0
#         norm: true
#       gain:
#         prob: 0.5
#         min_gain_dbfs: -10.0
#         max_gain_dbfs: 10.0
#         norm: true
#     num_workers: 16
#     pin_memory: true
#
# [NeMo W 2023-09-05 05:19:30 modelPT:168] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     manifest_filepath: /manifests/ami_dev_0.63.json,/manifests/freesound_background_dev.json,/manifests/freesound_laughter_dev.json,/manifests/ch120_moved_0.63.json,/manifests/fisher_2005_500_speech_sampled.json,/manifests/google_dev_manifest.json,/manifests/musan_music_dev.json,/manifests/mandarin_dev.json,/manifests/german_dev.json,/manifests/spanish_dev.json,/manifests/french_dev.json,/manifests/russian_dev.json
#     sample_rate: 16000
#     labels:
#     - background
#     - speech
#     batch_size: 256
#     shuffle: false
#     val_loss_idx: 0
#     num_workers: 16
#     pin_memory: true
#
# [NeMo W 2023-09-05 05:19:30 modelPT:174] Please call the ModelPT.setup_test_data() or ModelPT.setup_multiple_test_data() method and provide a valid configuration file to setup the test data loader(s).
#     Test config :
#     manifest_filepath: null
#     sample_rate: 16000
#     labels:
#     - background
#     - speech
#     batch_size: 128
#     shuffle: false
#     test_loss_idx: 0
# [NeMo I 2023-09-05 05:19:30 features:289] PADDING: 16
# [NeMo I 2023-09-05 05:19:30 save_restore_connector:249] Model EncDecClassificationModel was successfully restored from /root/.cache/torch/NeMo/NeMo_1.21.0rc0/vad_multilingual_marblenet/670f425c7f186060b7a7268ba6dfacb2/vad_multilingual_marblenet.nemo.
# [NeMo I 2023-09-05 05:19:30 clustering_diarizer:157] Loading pretrained titanet_large model from NGC
# [NeMo I 2023-09-05 05:19:30 cloud:68] Downloading from: https://api.ngc.nvidia.com/v2/models/nvidia/nemo/titanet_large/versions/v1/files/titanet-l.nemo to /root/.cache/torch/NeMo/NeMo_1.21.0rc0/titanet-l/11ba0924fdf87c049e339adbf6899d48/titanet-l.nemo
# [NeMo I 2023-09-05 05:19:34 common:913] Instantiating model from pre-trained checkpoint
# [NeMo W 2023-09-05 05:19:34 modelPT:161] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     manifest_filepath: /manifests/combined_fisher_swbd_voxceleb12_librispeech/train.json
#     sample_rate: 16000
#     labels: null
#     batch_size: 64
#     shuffle: true
#     is_tarred: false
#     tarred_audio_filepaths: null
#     tarred_shard_strategy: scatter
#     augmentor:
#       noise:
#         manifest_path: /manifests/noise/rir_noise_manifest.json
#         prob: 0.5
#         min_snr_db: 0
#         max_snr_db: 15
#       speed:
#         prob: 0.5
#         sr: 16000
#         resample_type: kaiser_fast
#         min_speed_rate: 0.95
#         max_speed_rate: 1.05
#     num_workers: 15
#     pin_memory: true
#
# [NeMo W 2023-09-05 05:19:34 modelPT:168] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     manifest_filepath: /manifests/combined_fisher_swbd_voxceleb12_librispeech/dev.json
#     sample_rate: 16000
#     labels: null
#     batch_size: 128
#     shuffle: false
#     num_workers: 15
#     pin_memory: true
# [NeMo I 2023-09-05 05:19:34 features:289] PADDING: 16
# [NeMo I 2023-09-05 05:19:35 save_restore_connector:249] Model EncDecSpeakerLabelModel was successfully restored from /root/.cache/torch/NeMo/NeMo_1.21.0rc0/titanet-l/11ba0924fdf87c049e339adbf6899d48/titanet-l.nemo.
# [NeMo I 2023-09-05 05:19:35 speaker_utils:93] Number of files to diarize: 1
# [NeMo I 2023-09-05 05:19:35 clustering_diarizer:309] Split long audio file to avoid CUDA memory issue
# splitting manifest: 100%|██████████| 1/1 [00:10<00:00, 10.41s/it]
# [NeMo I 2023-09-05 05:19:46 classification_models:273] Perform streaming frame-level VAD
# [NeMo I 2023-09-05 05:19:46 collections:301] Filtered duration for loading collection is  0.00 hours.
# [NeMo I 2023-09-05 05:19:46 collections:302] Dataset loaded with 10 items, total duration of  0.13 hours.
# [NeMo I 2023-09-05 05:19:46 collections:304] # 10 files loaded accounting to # 1 labels
# vad: 100%|██████████| 10/10 [00:06<00:00,  1.43it/s]
# [NeMo I 2023-09-05 05:19:53 clustering_diarizer:262] Converting frame level prediction to speech/no-speech segment in start and end times format.
# creating speech segments: 100%|██████████| 1/1 [00:00<00:00,  2.22it/s]
# [NeMo I 2023-09-05 05:19:53 clustering_diarizer:287] Subsegmentation for embedding extraction: scale0, ./diarized/speaker_outputs/subsegments_scale0.json
# [NeMo I 2023-09-05 05:19:53 clustering_diarizer:343] Extracting embeddings for Diarization
# [NeMo I 2023-09-05 05:19:53 collections:301] Filtered duration for loading collection is  0.00 hours.
# [NeMo I 2023-09-05 05:19:53 collections:302] Dataset loaded with 616 items, total duration of  0.26 hours.
# [NeMo I 2023-09-05 05:19:53 collections:304] # 616 files loaded accounting to # 1 labels
# [1/3] extract embeddings: 100%|██████████| 20/20 [00:01<00:00, 10.93it/s]
# [NeMo I 2023-09-05 05:19:55 clustering_diarizer:287] Subsegmentation for embedding extraction: scale1, ./diarized/speaker_outputs/subsegments_scale1.json
# [NeMo I 2023-09-05 05:19:55 clustering_diarizer:343] Extracting embeddings for Diarization
# [NeMo I 2023-09-05 05:19:55 collections:301] Filtered duration for loading collection is  0.00 hours.
# [NeMo I 2023-09-05 05:19:55 collections:302] Dataset loaded with 925 items, total duration of  0.26 hours.
# [NeMo I 2023-09-05 05:19:55 collections:304] # 925 files loaded accounting to # 1 labels
# [2/3] extract embeddings: 100%|██████████| 29/29 [00:02<00:00, 13.93it/s]
# [NeMo I 2023-09-05 05:19:57 clustering_diarizer:287] Subsegmentation for embedding extraction: scale2, ./diarized/speaker_outputs/subsegments_scale2.json
# [NeMo I 2023-09-05 05:19:57 clustering_diarizer:343] Extracting embeddings for Diarization
# [NeMo I 2023-09-05 05:19:57 collections:301] Filtered duration for loading collection is  0.00 hours.
# [NeMo I 2023-09-05 05:19:57 collections:302] Dataset loaded with 1850 items, total duration of  0.26 hours.
# [NeMo I 2023-09-05 05:19:57 collections:304] # 1850 files loaded accounting to # 1 labels
# [3/3] extract embeddings: 100%|██████████| 58/58 [00:02<00:00, 19.72it/s]
# clustering: 100%|██████████| 1/1 [00:03<00:00,  3.08s/it]
# [NeMo I 2023-09-05 05:20:04 clustering_diarizer:464] Outputs are saved in /kaggle/working/diarized directory
# [NeMo I 2023-09-05 05:20:04 der:176] Cumulative Results for collar 0.25 sec and ignore_overlap False:
#      FA: 0.0000	 MISS 0.0000	                 Diarization ER: 0.0000	, Confusion ER:0.0000

# %% [markdown]
# ## 合并

# %% [markdown]
# 设定说话人的名字，按照说话的顺序，写入speakers

# %%
speakers = ["ハルクさん","鍋島さん"]

speaker_ts = []
with open('./diarized/pred_rttms/audio_16k.rttm', 'r') as f:
    lines = f.readlines()
    for line in lines:
        line_list = line.split(' ')
        s = int(float(line_list[5]) * 1000)
        e = s + int(float(line_list[8]) * 1000)
        speaker_ts.append([s, e, int(line_list[11].split('_')[-1])])

def calculate_overlap_percentage(a_start, a_end, b_start, b_end):
    overlap_start = max(a_start, b_start)
    overlap_end = min(a_end, b_end)

    if overlap_start <= overlap_end:
        overlap_duration = overlap_end - overlap_start
        a_duration = a_end - a_start
        b_duration = b_end - b_start

        overlap_percentage = max(overlap_duration / min(a_duration, b_duration), overlap_duration / max(a_duration, b_duration))

        return overlap_percentage

    return 0.0

def find_max_overlap_or_closest(start, end, array, getter=lambda item: (item[0], item[1])):
    max_overlap_percentage = 0.0
    max_overlap_element = None
    closest_element = None
    closest_distance = float('inf')

    for item in array:
        a_start, a_end = getter(item)

        overlap_percentage = calculate_overlap_percentage(a_start, a_end, start, end)

        if overlap_percentage > max_overlap_percentage:
            max_overlap_percentage = overlap_percentage
            max_overlap_element = item

        b_midpoint = (start + end) / 2
        a_midpoint = (a_start + a_end) / 2
        distance = abs(b_midpoint - a_midpoint)

        if distance < closest_distance:
            closest_distance = distance
            closest_element = item

    return max_overlap_percentage, closest_element if max_overlap_percentage == 0.0 else max_overlap_element

draft = ''
for wrd_dict in word_ts:
    ws, we, wrd = int(wrd_dict['start'] * 1000), int(wrd_dict['end'] * 1000), wrd_dict['text']
    max_overlap_percentage, element = find_max_overlap_or_closest(ws, we, speaker_ts)
    if max_overlap_percentage < 0.5:
      print("Warning: max_overlap_percentage:%.2fs, [%.2fs -> %.2fs]「%s」" % (max_overlap_percentage, ws/1000, we/1000, wrd))
    draft += "%s: 「%s」\n" % (speakers[element[2]], wrd)
print(draft)
# Out:
# ハルクさん: 「計算式プラグインはやっぱり便利ですか?」
# 鍋島さん: 「便利ですね。やっぱり元々のKintonの計算フィールドって結局、」
# 鍋島さん: 「文字列1行と計算フィールドにしか入らないんですけど。」
# ハルクさん: 「はい、もうKintonさんある。」
# ハルクさん: 「今日はですね、後ろまたなべちゃんを呼んで、」
# ハルクさん: 「備品管理のKinton活用事例っていうのをご紹介していきたいなと思います。」
# ハルクさん: 「備品管理だけじゃなくて、僕らが最近教えている計算式プラグインを使った事例となりますので、」
# ハルクさん: 「こんなこともできるんだよっていうのを参考になればいいかなと思っております。」
# ハルクさん: 「うちのなべちゃんはですね、クルーデータとか、計算式プラグインをひたすら使いまくってますから、」
# ハルクさん: 「それ実際にお客さんの導入事例としてあるということだったので、」
# ハルクさん: 「持ち込み企画として動画に撮っております。」
# ハルクさん: 「ということで、じゃあなべちゃん、まずは実際に概要の部分だけ共有してもらった上で、」
# ハルクさん: 「画面共有してデモを見せる順番でお願いします。」
# 鍋島さん: 「アプリの概要ですね。」
# 鍋島さん: 「わかりました。アプリ的には、社内の備品管理っていうところを目指しています。」
# 鍋島さん: 「外国人向けの日本語教育されている会社さんの事例で作ったやつで、」
# 鍋島さん: 「その日本語のテティスト周り、同じテティストも10冊ぐらい持っていたとして、」
# 鍋島さん: 「その10冊それぞれに番号を付けて管理しています。」
# 鍋島さん: 「今誰が借りてるっていうのがわかるようにしてほしいっていう話があったので、」
# 鍋島さん: 「それで作ったアプリっていうのを今回、事例として中身は少し入れ替えたり、」
# 鍋島さん: 「中のレコードとかは僕らがオリジナルで作った状態にはなるんですけど、」
# 鍋島さん: 「それをお見せできればと思います。」
# ハルクさん: 「いわゆるそのボールペンとか鉛筆みたいな消耗品の管理じゃなくて、」
# ハルクさん: 「消耗しないものでね、本とかマイメーター、その教科書みたいな感じで、」
# ハルクさん: 「一つ一つ固有で管理をしていて、例えば教科書のAは誰が入れてるっていうのを」
# ハルクさん: 「しかしたいって言った目的のアプリだね。」
# 鍋島さん: 「そうです。工具とかでも使えるかなと思ってるんですよ。」
# ハルクさん: 「確かにOKです。じゃあちょっとお願いします。」
# 鍋島さん: 「じゃあ画面共有して見せていきます。」
# 鍋島さん: 「まず、会社の備品っていうのはご所属に適当に作ってるだけで、」
# 鍋島さん: 「実際もっと種類が多くても大丈夫です。」
# 鍋島さん: 「例えば、一番のこのケーブルを借りようとした時は、」
# 鍋島さん: 「レコード、ちょうど今借りた状態になってますね。」
# 鍋島さん: 「一回ちょっと返したってことにして、」
# 鍋島さん: 「借りる時、プラスで量を増やしていただくと、こういうふうに作られてきます。」
# 鍋島さん: 「これで保存をかけてもらったら、僕が今借りてる状態ですっていうのがわかります。」
# 鍋島さん: 「一覧の方に戻っていくと、僕が借りてるってことで、」
# 鍋島さん: 「私が借りてるものっていうリストに出てきます。」
# 鍋島さん: 「他の方にとっては、全体の中の貸し出し可能なやつっていうことで、」
# 鍋島さん: 「さっきもともと5種類あったんですけど、」
# 鍋島さん: 「5種類のうち2つちょっと今人が借りてるので、」
# 鍋島さん: 「残り3つが使える状態ですよ。」
# 鍋島さん: 「さらに貸し出し中の備品っていうところでは、」
# 鍋島さん: 「誰が借りてますよっていうのが見れるようになってます。」
# ハルクさん: 「これは同じ品名HDMIケーブルで1メートルとなってるけど、」
# ハルクさん: 「備品管理番号は違うから、」
# ハルクさん: 「要はHDMIケーブルが2つあるんだけど、」
# ハルクさん: 「それぞれ別個で1個ずつ管理してるってことだよね。」
# 鍋島さん: 「そうです。返すときは、返した日っていうのを入れてもらって、」
# 鍋島さん: 「保存書きでもらったら大丈夫です。」
# 鍋島さん: 「こうなると、今一応僕が借りてる状態じゃなくなってるので、」
# 鍋島さん: 「私が借りてるものっていうのにはなくない。」
# 鍋島さん: 「だいたいこういうなんか備品系って、」
# 鍋島さん: 「最後返ってきたとき誰かがチェックすると思うんですよ。」
# 鍋島さん: 「壊れてないかとか、破れてないかとか。」
# 鍋島さん: 「なので、管理部チェック待ち備品っていうところに入っていきます。」
# 鍋島さん: 「管理部の方がチェックしてもらって、」
# 鍋島さん: 「壊れてないよっていうのを確認してもらったら、」
# 鍋島さん: 「確認っていうところにチェック入れてください。」
# 鍋島さん: 「そしたら、チェック待ちが終わって、」
# 鍋島さん: 「貸出可能な備品リストの方にまた戻っていくと。」
# 鍋島さん: 「こういうふうになってます。」
# ハルクさん: 「一般的なよくある備品管理の仕組みであって、」
# ハルクさん: 「ちょっとこれはかなり簡単に作ってるけど、」
# ハルクさん: 「単純にテーブルで借りたら、テーブルを追加して、」
# ハルクさん: 「借りた日付を入れると。」
# ハルクさん: 「再返却したら、そのテーブルに対して返却費を入れてあげて、」
# ハルクさん: 「最終的に管理部が問題ないよってチェック付けたら、」
# ハルクさん: 「一覧で表示制御を空けているっていう感じだよね。」
# ハルクさん: 「はい。」
# ハルクさん: 「今回は、この計算式プラグインをどこで使っているか教えてもらっていい?」
# 鍋島さん: 「元々の作りとしては、テーブルの最後のところに追加しても、」
# 鍋島さん: 「最後今誰が借りているのっていうことかは、」
# 鍋島さん: 「自分で入力しないといけなかったんですよ。」
# 鍋島さん: 「だんだん伸びてくると、やっぱり下の方に行って、」
# 鍋島さん: 「こっちにも入れてって、なかなかやってくれなくなったりもするので、」
# 鍋島さん: 「ここらへん自動化したいなっていう気持ちがあって、」
# 鍋島さん: 「計算してプラグインの中身としては、」
# 鍋島さん: 「テーブルの一番下の量の内容っていうのを、」
# 鍋島さん: 「ここに複製するようにしています。」
# 鍋島さん: 「例えば、こうするとこういうふうに変わっていくのに。」
# ハルクさん: 「分かりましたかね?」
# ハルクさん: 「この一番下の今日、小川晴くって入れたものが、」
# ハルクさん: 「自動で、ここのユーザー選択フィールドに反映するようになってるんですよ。」
# ハルクさん: 「これは均等に標準機能じゃできなくて、」
# ハルクさん: 「テーブル内にある情報をテーブル外に移すっていうのは、」
# ハルクさん: 「サム関数とかはできますけど、」
# ハルクさん: 「こういった処理はできないんですね。」
# ハルクさん: 「もともとは、この最後に借りた人っていうところを基準に、」
# ハルクさん: 「さっきの一覧でいろいろ表示制御をしてるわけなんですけど、」
# ハルクさん: 「一番下にテーブル入力して、さらに最後に借りた人に手入力するっていうのは、」
# ハルクさん: 「面倒されてるっていうことだったので、」
# ハルクさん: 「計算式プラグインを使ってあげると、」
# ハルクさん: 「一番下の行に入っているユーザーを、」
# ハルクさん: 「最後に借りた人に自動で入ってくるようにするっていうか、」
# ハルクさん: 「制御して自動化したっていう事例だよね。」
# 鍋島さん: 「そうですね。」
# ハルクさん: 「計算式プラグインの事例ですね。」
# ハルクさん: 「ということで、今回はかなり簡単な事例ではあるんですけど、」
# ハルクさん: 「実際に備品の価値出し管理アプリの均等事例となります。」
# ハルクさん: 「計算式プラグインを使うと、」
# ハルクさん: 「こういう細かいこともできるよっていうところで、」
# ハルクさん: 「僕たちは計算式プラグイン、最近かなり対応しておりますので、」
# ハルクさん: 「ちょっとした機能とかを盛り込みたいという時には、」
# ハルクさん: 「こういった風にサクッとできたりもしますので、」
# ハルクさん: 「ぜひ参考にしてみてください。」
# ハルクさん: 「せっかくからちょっと裏側の設定画面見せようか、」
# ハルクさん: 「計算式プラグイン。」
# 鍋島さん: 「こんな感じになってます。」
# 鍋島さん: 「このフィールドに、こういう風な計算式に従って、」
# 鍋島さん: 「データを入れろというのを書いてます。」
# ハルクさん: 「これはテーブルの一番下の行のデータを取得するっていう計算式かな。」
# 鍋島さん: 「そうです。ラストがテーブルの一番下の行っていうので、」
# 鍋島さん: 「セットコードっていうのが、」
# 鍋島さん: 「ユーザー選択フィールドにデータを入れたいっていう時に使うやつです。」
# ハルクさん: 「それをフィールドコードの最後の行の指名っていう、」
# ハルクさん: 「さっきのユーザー選択フィールドに指定してあげることによって、」
# ハルクさん: 「テーブルの一番下のユーザー選択の情報を引っこ抜いてきて、」
# ハルクさん: 「最後の行の指名っていうユーザー選択フィールドに反映するようにしてるっていう計算式だね。」
# ハルクさん: 「そうです。」
# ハルクさん: 「この下のやつも同じかな。」
# ハルクさん: 「最新の確認状態ってことで、いわゆる管理部が最後に確認したかどうかっていうのも、」
# ハルクさん: 「テーブル外に持ってきたようで、だから同じような計算式を組んで設定してあげるという。」
# 鍋島さん: 「そうですね。こちらとチェックボックスのフィールドに計算式が使えるようになっています。」
# ハルクさん: 「なるほど。という感じで計算式プラグインはやっぱり便利ですか?」
# 鍋島さん: 「便利ですね。やっぱり元々のKintonの計算フィールドって、」
# 鍋島さん: 「結局は文字列一行と計算フィールドにしか入らないんですけど、」
# 鍋島さん: 「それをユーザー選択だったり、チェックボックスだったり、あるいはドロップダウンとか、」
# 鍋島さん: 「そういうところにも使えるようになりますし、」
# 鍋島さん: 「計算式の中身にユーザー選択フィールドの中身って使えないんですよ。」
# ハルクさん: 「ないね。」
# 鍋島さん: 「カレンダー型の一覧とか作ろうとした後にユーザー選択と何かこう、」
# 鍋島さん: 「文字列一行を結合しようとしたら、ユーザー選択使えないじゃんってなって止まるってよくあるんですけど、」
# 鍋島さん: 「それも使えるようになります。」
# ハルクさん: 「確かにね。ということで、」
# ハルクさん: 「もっともっとは計算式プラグインは鍋ちゃんが見つけてきたんだよね。」
# ハルクさん: 「鍋ちゃんが見つけてきて、ペパコミ内でこれいいねみたいな感じで、」
# ハルクさん: 「結構導入率が高くなっているという感じで。」
# 鍋島さん: 「もう一人毎日来ましたもんね。」
# ハルクさん: 「そうそうそう。これやばいねみたいな。」
# ハルクさん: 「今回は僕たちが予行して、計算式プラグインに突入した事例ということで、」
# ハルクさん: 「面白いかなと思って動画に撮らせていただきました。」
# ハルクさん: 「ということで今日はね、うちの担当の鍋ちゃんも呼んで、」
# ハルクさん: 「備品管理のデモということで、」
# ハルクさん: 「実際お客様にやった計算式プラグインを使った事例をご紹介させていただきました。」
# ハルクさん: 「参考になりましたら、ぜひチャンネル登録とかいいねをお待ちしております。」
# ハルクさん: 「他にもこんなことをやってほしいとかあればですね、」
# ハルクさん: 「コメントいただければなるべく対応するようにしますので、よろしくお願いします。」
# ハルクさん: 「ということで今日は以上となります。」
# ハルクさん: 「これからも近藤大学大学の話をしていきまして、」
# ハルクさん: 「チャンネル登録もぜひ本日もありがとうございました。」
# ハルクさん: 「また近藤大学の話をしましょう。バイバーイ。」

# %% [markdown]
# ## Azure OpanAI ChatGPT 总结

# %% [markdown]
# 设定你的Azure OpenAI信息
# 参考：
# https://github.com/openai/openai-python#microsoft-azure-endpoints

# %%
import openai

openai.api_type = "azure"
openai.api_base = ""
openai.api_version = "2023-03-15-preview"
openai.api_key = ""
engine = ""
model = "gpt-3.5-turbo-16k"
max_tokens = 16 * 1024

# %%
import tiktoken

prompt = "I want you to act as a conference summarization assistant and a multilingual translator. I will provide you with transcribed texts from the conference in different languages. You need to correct homophones and condense the content into summaries, emphasizing the key points of each speaker. I request that you provide the output in JSON format, including the following fields: The 'title' field will store the summarized title, which should not exceed 50 words. The 'summary' field will contain the summary you generate. Here is the conference content:"

encoding = tiktoken.encoding_for_model(model)
system_tokens = len(encoding.encode(prompt))
tokens_every_message = 3
tokens_res_assistant = 3
pre_tokens = len(encoding.encode("system")) + len(encoding.encode("user")) + tokens_res_assistant + 2 * tokens_every_message
total_tokens = len(encoding.encode(draft)) + pre_tokens + system_tokens
print(f"This request consumed {total_tokens} tokens.")
max_res_tokens = max_tokens - total_tokens -1

if max_res_tokens < 0:
    print("Warning: This request has exceeded the maximum processing limit of GPT. Please change the model.")
    exit()
if max_res_tokens < 400:
    print("Warning: The response for this request is fewer than 400 tokens. Please take note.")

completion = openai.ChatCompletion.create(
  engine=engine,
  messages = [
    {"role": "system", "content": prompt},
    {"role": "user", "content": draft}
  ],
  temperature=0.7,
  max_tokens=max_res_tokens,
  top_p=0.95,
  frequency_penalty=0,
  presence_penalty=0,
  stop=None)
result  = completion.choices[0].message.content
print(result)
# Out:
# This request consumed 5238 tokens.
# {
#   "title": "備品管理のKinton活用事例",
#   "summary": "ハルクさんは備品管理のKinton活用事例を紹介しました。備品管理アプリは消耗品ではなく、固有の備品の管理を目的としており、借りた人の情報や貸出可能な備品のリストが表示されます。さらに、計算式プラグインを使って自動化された機能も紹介されました。鍋島さんはアプリの概要や計算式プラグインの使い方を説明しました。計算式プラグインはテーブルの最後の行の情報を他のフィールドに自動的に反映させることができます。この事例は計算式プラグインの便利さを示し、導入率の高さも紹介されました。"
# }

# %% [markdown]
# ## 将总结内容上传

# %% [markdown]
# 设定kintone app信息
# 如domain设定为 xxxx.cybozu.cn 或者 xxxx.cybozu.com
# app_id为数字
# api_token的为对应的app的有添加权限的token

# %%
kintone_domain = ""
app_id = 1
api_token = ""

# %%
import json
import requests

info = json.loads(result)
url = f"https://{kintone_domain}/k/v1/record.json"
headers = {
    "Content-Type": "application/json",
    "X-Cybozu-API-Token":api_token,
}
data = {
    "app":app_id,
    "record":{
        'title':{
            'value':info['title']
        },
        'summary':{
            'value':info['summary']
        }
    }
}
resp=requests.post(url,json=data,headers=headers)
print(resp.text)
# Out:
# {"id":"2","revision":"1"}
